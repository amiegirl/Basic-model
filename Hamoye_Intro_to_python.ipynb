# %% [markdown]
# <a href="https://colab.research.google.com/github/amiegirl/Basic-model/blob/master/Hamoye_Intro_to_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df_dict={'Country':['Ghana','Kenya','Nigeria','Togo'],'Capital':['Accra','Nairobi','Abuja','Lome'],'Population':[10000,8500,35000,12000],'Age':[60,70,80,75]}
df=pd.DataFrame(df_dict,index=[2,4,6,8])
print(df)
# Out:
#    Country  Capital  Population  Age
# 2    Ghana    Accra       10000   60
# 4    Kenya  Nairobi        8500   70
# 6  Nigeria    Abuja       35000   80
# 8     Togo     Lome       12000   75

# %%
df.iloc[3]
# Out:
# Country        Togo
# Capital        Lome
# Population    12000
# Age              75
# Name: 8, dtype: object

# %%
fuel_data.isnull().sum()
# Out:
# record_id                         0
# utility_id_ferc1                  0
# report_year                       0
# plant_name_ferc1                  0
# fuel_type_code_pudl               0
# fuel_unit                       180
# fuel_qty_burned                   0
# fuel_mmbtu_per_unit               0
# fuel_cost_per_unit_burned         0
# fuel_cost_per_unit_delivered      0
# fuel_cost_per_mmbtu               0
# dtype: int64

# %%
import pandas as pd
url='https://raw.githubusercontent.com/WalePhenomenon/climate_change/master/fuel_ferc1.csv'
fuel_data=pd.read_csv(url,error_bad_lines=False)
fuel_data.describe(include='all')
# Out:
#                      record_id  ...  fuel_cost_per_mmbtu
# count                    29523  ...         29523.000000
# unique                   29523  ...                  NaN
# top     f1_fuel_2004_12_7_0_11  ...                  NaN
# freq                         1  ...                  NaN
# mean                       NaN  ...            19.304354
# std                        NaN  ...          2091.540939
# min                        NaN  ...           -41.501000
# 25%                        NaN  ...             1.940000
# 50%                        NaN  ...             4.127000
# 75%                        NaN  ...             7.745000
# max                        NaN  ...        359278.000000
#
# [11 rows x 11 columns]

# %%
fuel_data.groupby('fuel_unit')['fuel_unit'].count()
fuel_data[['fuel_unit']]=fuel_data[['fuel_unit']].fillna(value='mcf')

# %%
fuel_data.isnull().sum()
# Out:
# record_id                       0
# utility_id_ferc1                0
# report_year                     0
# plant_name_ferc1                0
# fuel_type_code_pudl             0
# fuel_unit                       0
# fuel_qty_burned                 0
# fuel_mmbtu_per_unit             0
# fuel_cost_per_unit_burned       0
# fuel_cost_per_unit_delivered    0
# fuel_cost_per_mmbtu             0
# dtype: int64

# %%
fuel_data.groupby('report_year')['report_year'].count()
fuel_data.groupby('fuel_type_code_pudl').first()
# Out:
#                                   record_id  ...  fuel_cost_per_mmbtu
# fuel_type_code_pudl                          ...
# coal                  f1_fuel_1994_12_1_0_7  ...                1.121
# gas                  f1_fuel_1994_12_2_0_10  ...                2.570
# nuclear               f1_fuel_1994_12_2_1_1  ...                0.450
# oil                   f1_fuel_1994_12_6_0_2  ...                5.469
# other                f1_fuel_1994_12_11_0_6  ...                2.335
# waste                 f1_fuel_1994_12_9_0_3  ...                1.072
#
# [6 rows x 10 columns]

# %%
fuel_df1=fuel_data.iloc[0:19000].reset_index(drop=True)
fuel_df2=fuel_data.iloc[19000:].reset_index(drop=True)

# %%
assert len(fuel_data)==(len(fuel_df1)+len(fuel_df2))

# %%
pd.merge(fuel_df1,fuel_df2,how="inner")
# Out:
# Empty DataFrame
# Columns: [record_id, utility_id_ferc1, report_year, plant_name_ferc1, fuel_type_code_pudl, fuel_unit, fuel_qty_burned, fuel_mmbtu_per_unit, fuel_cost_per_unit_burned, fuel_cost_per_unit_delivered, fuel_cost_per_mmbtu]
# Index: []

# %%
pd.merge(fuel_df1,fuel_df2,how="outer")
# Out:
#                      record_id  ...  fuel_cost_per_mmbtu
# 0        f1_fuel_1994_12_1_0_7  ...                1.121
# 1       f1_fuel_1994_12_1_0_10  ...                1.120
# 2        f1_fuel_1994_12_2_0_1  ...                1.650
# 3        f1_fuel_1994_12_2_0_7  ...                1.970
# 4       f1_fuel_1994_12_2_0_10  ...                2.570
# ...                        ...  ...                  ...
# 29518  f1_fuel_2018_12_12_0_13  ...                9.030
# 29519   f1_fuel_2018_12_12_1_1  ...                6.950
# 29520  f1_fuel_2018_12_12_1_10  ...                8.990
# 29521  f1_fuel_2018_12_12_1_13  ...                1.110
# 29522  f1_fuel_2018_12_12_1_14  ...               11.680
#
# [29523 rows x 11 columns]

# %%
pd.merge(fuel_df1,fuel_df2,how="left")
# Out:
#                       record_id  ...  fuel_cost_per_mmbtu
# 0         f1_fuel_1994_12_1_0_7  ...                1.121
# 1        f1_fuel_1994_12_1_0_10  ...                1.120
# 2         f1_fuel_1994_12_2_0_1  ...                1.650
# 3         f1_fuel_1994_12_2_0_7  ...                1.970
# 4        f1_fuel_1994_12_2_0_10  ...                2.570
# ...                         ...  ...                  ...
# 18995   f1_fuel_2009_12_182_1_9  ...                4.711
# 18996  f1_fuel_2009_12_182_1_10  ...               14.634
# 18997  f1_fuel_2009_12_182_1_13  ...                1.107
# 18998  f1_fuel_2009_12_182_1_14  ...               15.102
# 18999    f1_fuel_2009_12_79_0_1  ...                1.727
#
# [19000 rows x 11 columns]

# %%
fuel_data.duplicated().any()
# Out:
# False

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(7,4))
plt.xticks(rotation=90)
fuel_unit=pd.DataFrame({'unit':['BBL','GAL','GRAMSU','KGU','MCF','MMBTU','MWDTH','MWHTH','TON'],'count':[7998,84,464,110,11354,180,95,100,8954]})
sns.barplot(data=fuel_unit,x='unit',y='count')
plt.xlabel('Fuel Unit')
# Out:
# Text(0.5, 0, 'Fuel Unit')

# %%
import pandas as pd
df_list=[['Portugal',35,94],['Argentina',33,93],['Brazil',30,92],['Brazil',40,92]]
df=pd.DataFrame(df_list,columns=['Country','Age','Overall'],index=[1,2,3,4])
print(df)
# Out:
#      Country  Age  Overall
# 1   Portugal   35       94
# 2  Argentina   33       93
# 3     Brazil   30       92
# 4     Brazil   40       92

# %%
df.shape
# Out:
# (4, 3)

# %%
df.iloc[2:]
# Out:
#   Country  Age  Overall
# 3  Brazil   30       92
# 4  Brazil   40       92

# %%
import pandas as pd

# %%
# !pip install fsspec

# %%
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/My Drive/Colab Notebooks/
# Out:
# /content/drive/My Drive/Colab Notebooks

# %%
df=pd.read_csv('FoodBalanceSheets_E_Africa_NOFLAG.csv',encoding='latin-1')
print(df)
# Out:
#        Area Code      Area  Item Code  ...     Y2016     Y2017     Y2018
# 0              4   Algeria       2501  ...  40551.00  41389.00  42228.00
# 1              4   Algeria       2501  ...      0.00      0.00      0.00
# 2              4   Algeria       2901  ...   3372.00   3341.00   3322.00
# 3              4   Algeria       2901  ...     94.72     92.82     91.83
# 4              4   Algeria       2901  ...     77.40     80.19     77.28
# ...          ...       ...        ...  ...       ...       ...       ...
# 60938        181  Zimbabwe       2899  ...     33.00     19.00     16.00
# 60939        181  Zimbabwe       2899  ...      2.35      1.33      1.08
# 60940        181  Zimbabwe       2899  ...      3.00      1.00      1.00
# 60941        181  Zimbabwe       2899  ...      0.08      0.04      0.04
# 60942        181  Zimbabwe       2899  ...      0.03      0.02      0.01
#
# [60943 rows x 12 columns]

# %%
df.describe()
# Out:
#           Area Code     Item Code  ...          Y2017          Y2018
# count  60943.000000  60943.000000  ...   59437.000000   59507.000000
# mean     134.265576   2687.176706  ...     140.917765     143.758381
# std       72.605709    146.055739  ...    1671.862359    1710.782658
# min        4.000000   2501.000000  ...   -1582.000000   -3396.000000
# 25%       74.000000   2562.000000  ...       0.000000       0.000000
# 50%      136.000000   2630.000000  ...       0.100000       0.070000
# 75%      195.000000   2775.000000  ...       9.000000       9.000000
# max      276.000000   2961.000000  ...  190873.000000  195875.000000
#
# [8 rows x 8 columns]

# %%
df['Item']
# Out:
# 0           Population
# 1           Population
# 2          Grand Total
# 3          Grand Total
# 4          Grand Total
#              ...
# 60938    Miscellaneous
# 60939    Miscellaneous
# 60940    Miscellaneous
# 60941    Miscellaneous
# 60942    Miscellaneous
# Name: Item, Length: 60943, dtype: object

# %%
df.isnull().sum()
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64
